# %% [markdown]
# **Performance of the method on artificial dataset**

# %%
precision = [79, 67, 65, 59, 58, 57, 54, 56, 53, 52, 52, 51, 51, 48, 50, 48, 47, 50, 50, 49]
recall = [79, 74, 70, 66, 65, 63, 60, 63, 60, 58, 59, 57, 57, 54, 56, 54, 52, 55, 54, 54]
dynamic = [100 for _ in range(20)]
structural = [91, 93, 95, 96, 97, 97, 97, 98, 98, 98, 98, 98, 99, 98, 99, 99, 99, 99, 99, 99]
networksize = [i for i in range(10, 201, 10)]

# %%
precision = [i/100 for i in precision]
recall = [i/100 for i in recall]
dynamic = [1 for _ in range(20)]
structural = [i/100 for i in structural]

# %%
import matplotlib.pyplot as plt

# %%
fig = plt.gcf()
fig.set_size_inches(12, 6.5)
axes = plt.gca()
plt.plot(networksize, precision, color='#FF7F50', marker='s', label='Precision', linewidth=3, markersize=10)
plt.plot(networksize, recall, color='gray', marker='^', label='Recall', linewidth=3, markersize=10)
plt.plot(networksize, dynamic, color='#6495ED', marker='D', label='Dynamics Accuracy', linewidth=3, markersize=10)
plt.plot(networksize, structural, color='#FFBF00', marker='o', label='Structural Accuracy', linewidth=3, markersize=10)
plt.legend(fontsize=14, loc='center right')
plt.xlabel('Size of networks', fontsize=14)
plt.ylabel('Performance value', fontsize=14)
plt.xticks(networksize)
axes.tick_params(axis='x', size=6, width=2)
axes.tick_params(axis='y', size=6, width=2)
plt.show()

# %%
plt.savefig('g_experiment.PNG')

# %% [markdown]
# **Comparison dynamic accuracy between methods on dataset without noise**

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
#DBN, MICRAT, MIBNI, MIDNI
size10 = [70.05, 80.75, 80.75, 97.1]
size50 = [70.35, 73.2, 79.8, 100]
size100 = [70.75, 73.45, 81.8, 100]
size200 = [71.5, 74.6, 83.35, 100]
#dbn = [70.05, 70.35, 70.75, 71.5]
#micrat = [80.75, 73.2, 73.45, 74.6]
#mibni = [80.75, 79.8, 81.8, 83.35]
#midni = [97.1, 100, 100, 100]
networksize = [10, 50, 100, 200]

# %%
methods = ("DBN", "MICRAT", "MIBNI", 'MIDNI')
dynamics_0noise = {
    'DBN' : (70.05, 70.35, 70.75, 71.5),
    'MICRAT' : (80.75, 73.2, 73.45, 74.6),
    'MIBNI' : (80.75, 79.8, 81.8, 83.35),
    'MIDNI' : (97.1, 100, 100, 100)
}
structural_0noise = {
    'DBN' : (68.05, 90.8, 95.3, 97.1),
    'MICRAT' : (67.9, 90.75, 95.2, 97.1),
    'MIBNI' : (63.8, 90.65, 95.05, 97.1),
    'MIDNI' : (28.6, 87.4, 94.1, 96.75)
}

x = np.arange(len(methods))  # the label locations
width = 0.2  # the width of the bars
multiplier = 0

fig, ax = plt.subplots(1,2)
fig.set_size_inches(18, 6.5)
for attribute, measurement in dynamics_0noise.items():
    offset = width * multiplier
    rects = ax[0].bar(x + offset, measurement, width, label=attribute)
    #ax.bar_label(rects, padding=3)
    multiplier += 1
    
multiplier = 0
for attribute, measurement in structural_0noise.items():
    offset = width * multiplier
    rects = ax[1].bar(x + offset, measurement, width, label=attribute)
    #ax.bar_label(rects, padding=3)
    multiplier += 1

# Add some text for labels, title and custom x-axis tick labels, etc.
ax[0].set_ylabel('Dynamics accuracy (%)', fontsize=12)
ax[0].set_xlabel('Size of networks', fontsize=12)
ax[0].set_xticks(x + 3*width/2)
ax[0].set_xticklabels(networksize)
ax[0].legend(loc='upper left')
ax[0].legend(loc='upper left')
ax[0].set_ylim(40, 105)

ax[1].set_ylabel('Structural accuracy (%)', fontsize=12)
ax[1].set_xlabel('Size of networks', fontsize=12)
ax[1].set_xticks(x + 3*width/2)
ax[1].set_xticklabels(networksize)
ax[1].legend(loc='upper left')
ax[1].set_ylim(20, 105)

plt.show()

# %% [markdown]
# **Dynamics accuracy**

# %%
methods = ("DBN", "MICRAT", "MIBNI", 'MIDNI')
dynamics_0noise = {
    'DBN' : (70.05, 70.35, 70.75, 71.5),
    'MICRAT' : (80.75, 73.2, 73.45, 74.6),
    'MIBNI' : (80.75, 79.8, 81.8, 83.35),
    'MIDNI' : (97.1, 100, 100, 100)
}
dynamics_5noise = {
    'DBN' : (68.4, 70.95, 70.45, 71.3),
    'MICRAT' : (70.05, 73.35, 73.7, 74.85),
    'MIBNI' : (79.25, 80.95, 81.65, 83.8),
    'MIDNI' : (97.95, 100, 100, 100)
}
dynamics_10noise = {
    'DBN' : (67.35, 71.1, 71.15, 70.8),
    'MICRAT' : (68.7, 74.7, 74.25, 75),
    'MIBNI' : (77.65, 82.45, 82.4, 84),
    'MIDNI' : (98.65, 100, 100, 100)
}

# %%
x = np.arange(len(methods))  # the label locations
width = 0.2  # the width of the bars
multiplier = 0

fig, ax = plt.subplots(3,1)
fig.set_size_inches(10, 14)
for attribute, measurement in dynamics_0noise.items():
    offset = width * multiplier
    rects = ax[0].bar(x + offset, measurement, width, label=attribute)
    #ax.bar_label(rects, padding=3)
    multiplier += 1
    
multiplier = 0
for attribute, measurement in dynamics_5noise.items():
    offset = width * multiplier
    rects = ax[1].bar(x + offset, measurement, width, label=attribute)
    #ax.bar_label(rects, padding=3)
    multiplier += 1
multiplier = 0
for attribute, measurement in dynamics_10noise.items():
    offset = width * multiplier
    rects = ax[2].bar(x + offset, measurement, width, label=attribute)
    #ax.bar_label(rects, padding=3)
    multiplier += 1

# Add some text for labels, title and custom x-axis tick labels, etc.
ax[0].set_ylabel('Dynamics accuracy (%)', fontsize=12)
#ax[0].set_xlabel('Size of networks', fontsize=12)
ax[0].set_xticks(x + 3*width/2)
ax[0].set_xticklabels(networksize)
ax[0].legend(loc='upper left')
ax[0].legend(loc='upper left')
ax[0].set_ylim(50, 105)
ax[0].set_title('(a) Dynamics accuracy on the dataset without noise')

ax[1].set_ylabel('Dynamics accuracy (%)', fontsize=12)
#ax[1].set_xlabel('Size of networks', fontsize=12)
ax[1].set_xticks(x + 3*width/2)
ax[1].set_xticklabels(networksize)
ax[1].legend(loc='upper left')
ax[1].set_ylim(50, 105)
ax[1].set_title('(b) Dynamics accuracy on the dataset with a 5% noise rate')

ax[2].set_ylabel('Dynamics accuracy (%)', fontsize=12)
ax[2].set_xlabel('Size of networks', fontsize=12)
ax[2].set_xticks(x + 3*width/2)
ax[2].set_xticklabels(networksize)
ax[2].legend(loc='upper left')
ax[2].set_ylim(50, 105)
ax[2].set_title('(c) Dynamics accuracy on the dataset with a 10% noise rate')

plt.show()

# %% [markdown]
# **Structural accuracy**

# %%
methods = ("DBN", "MICRAT", "MIBNI", 'MIDNI')
structural_0noise = {
    'DBN' : (68.05, 90.8, 95.3, 97.1),
    'MICRAT' : (67.9, 90.75, 95.2, 97.1),
    'MIBNI' : (63.8, 90.65, 95.05, 97.1),
    'MIDNI' : (28.6, 87.4, 95.05, 96.75)
}
structural_5noise = {
    'DBN' : (67.75, 91, 95.3, 97.05),
    'MICRAT' : (68.2, 91.3, 95.15, 97),
    'MIBNI' : (63.85, 91, 95.15, 97),
    'MIDNI' : (29.9, 87.55, 93.95, 96.7)
}
structural_10noise = {
    'DBN' : (69.6, 91.25, 95.25, 97.15),
    'MICRAT' : (68.95, 90.75, 95.25, 97),
    'MIBNI' : (63.9, 90.6, 95.2, 97),
    'MIDNI' : (30.45, 87.3, 94.05, 96.7)
}

# %%
x = np.arange(len(methods))  # the label locations
width = 0.2  # the width of the bars
multiplier = 0

fig, ax = plt.subplots(3,1)
fig.set_size_inches(10, 14)
for attribute, measurement in structural_0noise.items():
    offset = width * multiplier
    rects = ax[0].bar(x + offset, measurement, width, label=attribute)
    #ax.bar_label(rects, padding=3)
    multiplier += 1
    
multiplier = 0
for attribute, measurement in structural_5noise.items():
    offset = width * multiplier
    rects = ax[1].bar(x + offset, measurement, width, label=attribute)
    #ax.bar_label(rects, padding=3)
    multiplier += 1
multiplier = 0
for attribute, measurement in structural_10noise.items():
    offset = width * multiplier
    rects = ax[2].bar(x + offset, measurement, width, label=attribute)
    #ax.bar_label(rects, padding=3)
    multiplier += 1

# Add some text for labels, title and custom x-axis tick labels, etc.
ax[0].set_ylabel('Structural accuracy (%)', fontsize=12)
#ax[0].set_xlabel('Size of networks', fontsize=12)
ax[0].set_xticks(x + 3*width/2)
ax[0].set_xticklabels(networksize)
ax[0].legend(loc='upper left')
ax[0].legend(loc='upper left')
ax[0].set_ylim(20, 105)
ax[0].set_title('(a) Structural accuracy on the dataset without noise')

ax[1].set_ylabel('Structural accuracy (%)', fontsize=12)
#ax[1].set_xlabel('Size of networks', fontsize=12)
ax[1].set_xticks(x + 3*width/2)
ax[1].set_xticklabels(networksize)
ax[1].legend(loc='upper left')
ax[1].set_ylim(20, 105)
ax[1].set_title('(b) Structural accuracy on the dataset with a 5% noise rate')

ax[2].set_ylabel('Structural accuracy (%)', fontsize=12)
ax[2].set_xlabel('Size of networks', fontsize=12)
ax[2].set_xticks(x + 3*width/2)
ax[2].set_xticklabels(networksize)
ax[2].legend(loc='upper left')
ax[2].set_ylim(20, 105)
ax[2].set_title('(c) Structural accuracy on the dataset with a 10% noise rate')

plt.show()

# %% [markdown]
# **Incomming links effect**

# %%
dynamic = [100, 100, 100, 100, 100, 100, 100, 99.6]
precision = [100, 96.5, 26.25, 13.4, 12.8, 13.85, 15.2, 13.85]
recall = [100, 97.8, 32.4, 13.15, 10, 9.05, 8.55, 2.85]
structural = [100, 99.85, 90.25, 86.05, 83.9, 81.85, 80.1, 78]
x_axis = [i for i in range(1,9)]

# %%
dynamic = [i/100 for i in dynamic]
precision = [i/100 for i in precision]
recall = [i/100 for i in recall]
structural = [i/100 for i in structural]

# %%
fig = plt.gcf()
fig.set_size_inches(12, 6.5)
axes = plt.gca()
plt.plot(x_axis, dynamic, color='#FF7F50', marker='s', label='Dynamics Accuracy', linewidth=3, markersize=10)
plt.plot(x_axis, structural, color='gray', marker='^', label='Structural Accuracy', linewidth=3, markersize=10)
plt.plot(x_axis, precision, color='#6495ED', marker='D', label='Precision', linewidth=3, markersize=10)
plt.plot(x_axis, recall, color='#a50fdb', marker='X', label='Recall', linewidth=3, markersize=10)
plt.legend(fontsize=14, loc='center right')
plt.xlabel('Number of incoming links', fontsize=14)
plt.ylabel('Performance value', fontsize=14)
plt.xticks(x_axis)
axes.tick_params(axis='x', size=6, width=2)
axes.tick_params(axis='y', size=6, width=2)
plt.show()
# coli

# %% [markdown]
# **Running time**

# %%
t_dbn_nonoise = (1.003245, 2.307282, 2.989227, 3.746556)
t_micrat_nonoise = (1.915136, 3.326438, 3.904851, 4.561537)
t_mibni_nonoise = (2.101747, 3.533664, 4.095068, 4.716666)
t_midni_nonoise = (2.079904, 3.499582, 4.095068, 4.690897)

# %%
t_dbn_5noise = (1.091667, 2.299289, 2.98985, 3.744215)
t_micrat_5noise = (1.873611, 3.28576, 3.890843, 4.551793)
t_mibni_5noise = (2.082247, 3.526785, 4.098891, 4.73816)
t_midni_5noise = (2.110926, 3.4974, 4.089935, 4.732472)

# %%
t_dbn_10noise = (0.975432, 2.285895, 2.986548, 3.740343)
t_micrat_10noise = (1.91169, 3.279393, 3.889699, 4.512209)
t_mibni_10noise = (2.083323, 3.52568, 4.107127, 4.71136)
t_midni_10noise = (2.109747, 3.489727, 4.096213, 4.707629)

# %%
networks = (10, 50, 100, 200)

# %%
fig, ax = plt.subplots(3,1)
fig.set_size_inches(8, 10)
ax[0].plot(networks, t_dbn_nonoise, color='#FF7F50', marker='s', label='DBN', linewidth=3, markersize=10)
ax[0].plot(networks, t_micrat_nonoise, color='gray', marker='^', label='MICRAT', linewidth=3, markersize=10)
ax[0].plot(networks, t_mibni_nonoise, color='#6495ED', marker='D', label='MIBNI', linewidth=3, markersize=10)
ax[0].plot(networks, t_midni_nonoise, color='#a50fdb', marker='X', label='MIDNI', linewidth=3, markersize=10)
ax[0].legend(fontsize=12, loc='lower right')
ax[0].set_xticks(networks)
ax[0].set_yticks((1, 2, 3, 4, 5))
ax[0].set_ylabel('Running time (log10 of millisecond)')
ax[0].set_title('(a)')

ax[1].plot(networks, t_dbn_5noise, color='#FF7F50', marker='s', label='DBN', linewidth=3, markersize=10)
ax[1].plot(networks, t_micrat_5noise, color='gray', marker='^', label='MICRAT', linewidth=3, markersize=10)
ax[1].plot(networks, t_mibni_5noise, color='#6495ED', marker='D', label='MIBNI', linewidth=3, markersize=10)
ax[1].plot(networks, t_midni_5noise, color='#a50fdb', marker='X', label='MIDNI', linewidth=3, markersize=10)
ax[1].legend(fontsize=12, loc='lower right')
ax[1].set_xticks(networks)
ax[1].set_yticks((1, 2, 3, 4, 5))
ax[1].set_ylabel('Running time (log10 of millisecond)')
ax[1].set_title('(b)')

ax[2].plot(networks, t_dbn_10noise, color='#FF7F50', marker='s', label='DBN', linewidth=3, markersize=10)
ax[2].plot(networks, t_micrat_10noise, color='gray', marker='^', label='MICRAT', linewidth=3, markersize=10)
ax[2].plot(networks, t_mibni_10noise, color='#6495ED', marker='D', label='MIBNI', linewidth=3, markersize=10)
ax[2].plot(networks, t_midni_10noise, color='#a50fdb', marker='X', label='MIDNI', linewidth=3, markersize=10)
ax[2].legend(fontsize=12, loc='lower right')
ax[2].set_xticks(networks)
ax[2].set_yticks((1, 2, 3, 4, 5))
ax[2].set_ylabel('Running time (log10 of millisecond)')
ax[2].set_xlabel('Size of networks')
ax[2].set_title('(c)')
# Out:
# Text(0.5, 1.0, '(c)')
